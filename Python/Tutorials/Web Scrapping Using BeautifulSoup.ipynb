# %% [markdown]
# # In this tutorial, you will learn about the following:
#
# • Data extraction from the web using Python's Beautiful Soup module
#
# • Data manipulation and cleaning using Python's Pandas library
#
# • Data visualization using Python's Matplotlib library
#
# The dataset used in this tutorial was taken from a 10K race that took place in Hillsboro, OR on June 2017. Specifically, you will analyze the performance of the 10K runners and answer questions such as:
#
# • What was the average finish time for the runners?
#
# • Did the runners' finish times follow a normal distribution?
#
# • Were there any performance differences between males and females of various age groups
#
#
# https://www.datacamp.com/community/tutorials/web-scraping-using-python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "http://www.hubertiming.com/results/2017GPTR10K"
html = urlopen(url)

# %%
soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# Print title

title = soup.title
print(title)
# Out:
# <title>2017 Intel Great Place to Run 10K \ Urban Clash Games Race Results</title>

# %%
# Print out the test

text = soup.get_text()
# print(soup.text)

# %%
all_links = soup.find_all('a')
# print(all_links)
for link in all_links:
    print(link.get("href"))
# Out:
# mailto:timing@hubertiming.com
# https://www.hubertiming.com/
# /results/2017GPTR
# /results/summary/2017GPTR10K
# #team
# #individual
# None
# None
# #tabs-1
# https://www.hubertiming.com/
# https://facebook.com/hubertiming/

# %%
rows = soup.find_all('tr')
print(rows[:10])
# Out:
# [<tr colspan="2"><b>10K:</b></tr>, <tr><td>Finishers:</td><td>577</td></tr>, <tr><td>Male:</td><td>414</td></tr>, <tr><td>Female:</td><td>163</td></tr>, <tr>
# <td>Award</td>
# <td>Name</td>
# <td>Combined Time</td>
# <td>1</td><td>2</td><td>3</td><td>4</td></tr>, <tr><td>1ST</td>
# <td>DTNA2</td>
# <td>02:54:41</td>
# <td>00:40:36 - ANDY WEDAM</td><td>00:44:05 - VASILIOS TSIRIMIAGOS</td><td>00:44:48 - ANDRE RAUCH</td><td>00:45:10 - JONATHAN PARSONS</td></tr>, <tr><td>2ND</td>
# <td>INTEL TEAM K</td>
# <td>03:01:02</td>
# <td>00:41:43 - WILLIAM BARRY</td><td>00:42:36 - EDDIE J FRIE</td><td>00:43:46 - SAMANTHA BAGLEY</td><td>00:52:55 - JOHN HAMILTON</td></tr>, <tr><td>3RD</td>
# <td>INTEL TEAM F</td>
# <td>03:06:06</td>
# <td>00:36:42 - NATHAN A SUSTERSIC</td><td>00:39:21 - DEREK G OSBORNE</td><td>00:52:47 - CODY L COVEY</td><td>00:57:16 - VIRAJ P MODAK</td></tr>, <tr><td>4TH</td>
# <td>DTNA1</td>
# <td>03:15:33</td>
# <td>00:40:28 - WITALI SPULING</td><td>00:46:45 - INGA ANDREYEVA</td><td>00:54:09 - KEATON WEISENBORN</td><td>00:54:10 - MAISIE WEISENBORN</td></tr>, <tr><td>5TH</td>
# <td>FXG1</td>
# <td>03:21:16</td>
# <td>00:42:56 - DAVID HERRON</td><td>00:46:35 - LEO SOTO</td><td>00:53:59 - TONY GONZALEZ</td><td>00:57:45 - ARINDA SCHRUM</td></tr>]

# %%
for row in rows:
    row_td = row.find_all('td')
print(row_td)
type(row_td)
# Out:
# [<td>577</td>, <td>443</td>, <td>LIBBY B MITCHELL</td>, <td>F</td>, <td>HILLSBORO</td>, <td>OR</td>, <td>1:41:18</td>, <td>16:20</td>, <td>163 of 163</td>, <td>F 36-45</td>, <td>56 of 56</td>, <td>0:52</td>, <td>1:42:10</td>, <td></td>]
# bs4.element.ResultSet

# %%
str_cells = str(row_td)
cleantext = BeautifulSoup(str_cells, "lxml").get_text()
print(cleantext)
# Out:
# [577, 443, LIBBY B MITCHELL, F, HILLSBORO, OR, 1:41:18, 16:20, 163 of 163, F 36-45, 56 of 56, 0:52, 1:42:10, ]

# %%
# Other way of removing HTML tags using Regular Expression(Not recommended)

import re

list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)
print(clean2)
type(clean2)
# Out:
# [577, 443, LIBBY B MITCHELL, F, HILLSBORO, OR, 1:41:18, 16:20, 163 of 163, F 36-45, 56 of 56, 0:52, 1:42:10, ]
# str

# %%
df = pd.DataFrame(list_rows)
df.head(10)
# Out:
#                                                    0
# 0                                                 []
# 1                                  [Finishers:, 577]
# 2                                       [Male:, 414]
# 3                                     [Female:, 163]
# 4           [Award, Name, Combined Time, 1, 2, 3, 4]
# 5  [1ST, DTNA2, 02:54:41, 00:40:36 - ANDY WEDAM, ...
# 6  [2ND, INTEL TEAM K, 03:01:02, 00:41:43 - WILLI...
# 7  [3RD, INTEL TEAM F, 03:06:06, 00:36:42 - NATHA...
# 8  [4TH, DTNA1, 03:15:33, 00:40:28 - WITALI SPULI...
# 9  [5TH, FXG1, 03:21:16, 00:42:56 - DAVID HERRON,...

# %%
df1 = df[0].str.split(',', expand=True)
df1.head(10)
# Out:
#             0              1               2                               3   \
# 0           []           None            None                            None
# 1  [Finishers:           577]            None                            None
# 2       [Male:           414]            None                            None
# 3     [Female:           163]            None                            None
# 4       [Award           Name   Combined Time                               1
# 5         [1ST          DTNA2        02:54:41           00:40:36 - ANDY WEDAM
# 6         [2ND   INTEL TEAM K        03:01:02        00:41:43 - WILLIAM BARRY
# 7         [3RD   INTEL TEAM F        03:06:06   00:36:42 - NATHAN A SUSTERSIC
# 8         [4TH          DTNA1        03:15:33       00:40:28 - WITALI SPULING
# 9         [5TH           FXG1        03:21:16         00:42:56 - DAVID HERRON
#
#                                  4                              5   \
# 0                              None                           None
# 1                              None                           None
# 2                              None                           None
# 3                              None                           None
# 4                                 2                              3
# 5   00:44:05 - VASILIOS TSIRIMIAGOS         00:44:48 - ANDRE RAUCH
# 6           00:42:36 - EDDIE J FRIE     00:43:46 - SAMANTHA BAGLEY
# 7        00:39:21 - DEREK G OSBORNE        00:52:47 - CODY L COVEY
# 8         00:46:45 - INGA ANDREYEVA   00:54:09 - KEATON WEISENBORN
# 9               00:46:35 - LEO SOTO       00:53:59 - TONY GONZALEZ
#
#                                6     7     8     9     10    11    12    13
# 0                            None  None  None  None  None  None  None  None
# 1                            None  None  None  None  None  None  None  None
# 2                            None  None  None  None  None  None  None  None
# 3                            None  None  None  None  None  None  None  None
# 4                              4]  None  None  None  None  None  None  None
# 5    00:45:10 - JONATHAN PARSONS]  None  None  None  None  None  None  None
# 6       00:52:55 - JOHN HAMILTON]  None  None  None  None  None  None  None
# 7       00:57:16 - VIRAJ P MODAK]  None  None  None  None  None  None  None
# 8   00:54:10 - MAISIE WEISENBORN]  None  None  None  None  None  None  None
# 9       00:57:45 - ARINDA SCHRUM]  None  None  None  None  None  None  None

# %%
df1[0] = df1[0].str.split('[')
df1.head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-c27e70a0914f> in <module>
# ----> 1 df1[0] = df1[0].str.split('[')
#       2 df1.head(10)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     169             # we're accessing the attribute of the class, i.e., Dataset.geo
#     170             return self._accessor
# --> 171         accessor_obj = self._accessor(obj)
#     172         # Replace the property with the accessor object. Inspired by:
#     173         # http://www.pydanny.com/cached-property.html
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py in __init__(self, data)
#    1794
#    1795     def __init__(self, data):
# -> 1796         self._validate(data)
#    1797         self._is_categorical = is_categorical_dtype(data)
#    1798
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py in _validate(data)
#    1816             # (instead of test for object dtype), but that isn't practical for
#    1817             # performance reasons until we have a str dtype (GH 9343)
# -> 1818             raise AttributeError("Can only use .str accessor with string "
#    1819                                  "values, which use np.object_ dtype in "
#    1820                                  "pandas")
#
# AttributeError: Can only use .str accessor with string values, which use np.object_ dtype in pandas

# %%
col_labels = soup.find_all('th')
print(col_labels)
# Out:
# [<th>Place</th>, <th>Bib</th>, <th>Name</th>, <th>Gender</th>, <th>City</th>, <th>State</th>, <th>Chip Time</th>, <th>Chip Pace</th>, <th>Gender Place</th>, <th>Age Group</th>, <th>Age Group Place</th>, <th>Time to Start</th>, <th>Gun Time</th>, <th>Team</th>]

# %%
all_headers = []
col_str = str(col_labels)
cleantext2 = BeautifulSoup(col_str, "lxml").get_text()
all_headers.append(cleantext2)
print(all_headers)
# Out:
# ['[Place, Bib, Name, Gender, City, State, Chip Time, Chip Pace, Gender Place, Age Group, Age Group Place, Time to Start, Gun Time, Team]']

# %%
df2 = pd.DataFrame(all_headers)
df2.head(10)
# Out:
#                                                    0
# 0  [Place, Bib, Name, Gender, City, State, Chip T...

# %%
df3 = df2[0].str.split(',', expand=True)
df3.head()
# Out:
#        0     1      2        3      4       5           6           7   \
# 0  [Place   Bib   Name   Gender   City   State   Chip Time   Chip Pace
#
#               8           9                 10              11         12  \
# 0   Gender Place   Age Group   Age Group Place   Time to Start   Gun Time
#
#        13
# 0   Team]

# %%
frames = [df3, df1]

df4 = pd.concat(frames)
df4.head(10)
# Out:
#        0              1               2                               3   \
# 0  [Place            Bib            Name                          Gender
# 0     NaN           None            None                            None
# 1     NaN           577]            None                            None
# 2     NaN           414]            None                            None
# 3     NaN           163]            None                            None
# 4     NaN           Name   Combined Time                               1
# 5     NaN          DTNA2        02:54:41           00:40:36 - ANDY WEDAM
# 6     NaN   INTEL TEAM K        03:01:02        00:41:43 - WILLIAM BARRY
# 7     NaN   INTEL TEAM F        03:06:06   00:36:42 - NATHAN A SUSTERSIC
# 8     NaN          DTNA1        03:15:33       00:40:28 - WITALI SPULING
#
#                                  4                              5   \
# 0                              City                          State
# 0                              None                           None
# 1                              None                           None
# 2                              None                           None
# 3                              None                           None
# 4                                 2                              3
# 5   00:44:05 - VASILIOS TSIRIMIAGOS         00:44:48 - ANDRE RAUCH
# 6           00:42:36 - EDDIE J FRIE     00:43:46 - SAMANTHA BAGLEY
# 7        00:39:21 - DEREK G OSBORNE        00:52:47 - CODY L COVEY
# 8         00:46:45 - INGA ANDREYEVA   00:54:09 - KEATON WEISENBORN
#
#                                6           7              8           9   \
# 0                       Chip Time   Chip Pace   Gender Place   Age Group
# 0                            None        None           None        None
# 1                            None        None           None        None
# 2                            None        None           None        None
# 3                            None        None           None        None
# 4                              4]        None           None        None
# 5    00:45:10 - JONATHAN PARSONS]        None           None        None
# 6       00:52:55 - JOHN HAMILTON]        None           None        None
# 7       00:57:16 - VIRAJ P MODAK]        None           None        None
# 8   00:54:10 - MAISIE WEISENBORN]        None           None        None
#
#                  10              11         12      13
# 0   Age Group Place   Time to Start   Gun Time   Team]
# 0              None            None       None    None
# 1              None            None       None    None
# 2              None            None       None    None
# 3              None            None       None    None
# 4              None            None       None    None
# 5              None            None       None    None
# 6              None            None       None    None
# 7              None            None       None    None
# 8              None            None       None    None

# %%
df5 = df4.rename(columns=df4.iloc[0])
df5.head()
# Out:
#    [Place    Bib   Name   Gender   City   State   Chip Time   Chip Pace  \
# 0  [Place    Bib   Name   Gender   City   State   Chip Time   Chip Pace
# 0     NaN   None   None     None   None    None        None        None
# 1     NaN   577]   None     None   None    None        None        None
# 2     NaN   414]   None     None   None    None        None        None
# 3     NaN   163]   None     None   None    None        None        None
#
#     Gender Place   Age Group   Age Group Place   Time to Start   Gun Time  \
# 0   Gender Place   Age Group   Age Group Place   Time to Start   Gun Time
# 0           None        None              None            None       None
# 1           None        None              None            None       None
# 2           None        None              None            None       None
# 3           None        None              None            None       None
#
#     Team]
# 0   Team]
# 0    None
# 1    None
# 2    None
# 3    None

# %%
df5.info()
df5.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 598 entries, 0 to 596
# Data columns (total 14 columns):
# [Place              1 non-null object
#  Bib                596 non-null object
#  Name               593 non-null object
#  Gender             593 non-null object
#  City               593 non-null object
#  State              593 non-null object
#  Chip Time          593 non-null object
#  Chip Pace          578 non-null object
#  Gender Place       578 non-null object
#  Age Group          578 non-null object
#  Age Group Place    578 non-null object
#  Time to Start      578 non-null object
#  Gun Time           578 non-null object
#  Team]              578 non-null object
# dtypes: object(14)
# memory usage: 70.1+ KB
# (598, 14)

# %%
df6 = df5.dropna(axis=0, how='any')

# %%
df7 = df6.drop(df6.index[0])
df7.info()
df7.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 14 columns):
# [Place              0 non-null object
#  Bib                0 non-null object
#  Name               0 non-null object
#  Gender             0 non-null object
#  City               0 non-null object
#  State              0 non-null object
#  Chip Time          0 non-null object
#  Chip Pace          0 non-null object
#  Gender Place       0 non-null object
#  Age Group          0 non-null object
#  Age Group Place    0 non-null object
#  Time to Start      0 non-null object
#  Gun Time           0 non-null object
#  Team]              0 non-null object
# dtypes: object(14)
# memory usage: 0.0+ bytes
# (0, 14)
